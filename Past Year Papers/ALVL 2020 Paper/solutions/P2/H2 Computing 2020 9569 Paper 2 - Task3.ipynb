# %%
#Task 3.1
def task3_1(quantity_of_data):
    noofBytes = 0
    hasError = False
    if len(quantity_of_data)>2:
        qtystr = quantity_of_data[:len(quantity_of_data)-2]
        unit = quantity_of_data[len(quantity_of_data)-2:] 
        
        if(qtystr.isdigit()):
            qty = int(qtystr)
            if unit=='KB':
                noofBytes = qty * pow(10,3)
            elif unit =='MB':
                noofBytes = qty * pow(10,6)
            elif unit =='GB':
                 noofBytes = qty * pow(10,9)
            elif unit =='TB':
                noofBytes = qty * pow(10,12)
            else:
                hasError = True
        else:
            hasError = True
    else:
            hasError = True
    
    if hasError:
        print("Invalid data")
        return 0
    else:
       # print("{}".format(noofBytes)) 
        return noofBytes
    

print("Correct data")
task3_1('80KB')
task3_1('80MB')
task3_1('80GB')
task3_1('80TB')
print("Error data")
task3_1('80K')
task3_1('80M')
task3_1('80G')
task3_1('80T')
task3_1('80kb')

print("Error data")
task3_1('80KB1')
task3_1('80MB2')
task3_1('80GB3')
task3_1('80TB4')
print("Error data")
task3_1('80')
task3_1('MB')
task3_1('0G')
task3_1('800 TB')



task3_1("8KB")
# Out:
# Correct data
# Error data
# Invalid data
# Invalid data
# Invalid data
# Invalid data
# Invalid data
# Error data
# Invalid data
# Invalid data
# Invalid data
# Invalid data
# Error data
# Invalid data
# Invalid data
# Invalid data
# Invalid data
# 8000

# %%
#Task 3.2

def task3_2(quantity_of_data):
    noofBytes = 0
    hasError = False
    unit=''
    qtystr=''
    qty=0
    if 'KB' in quantity_of_data and len(quantity_of_data)>2:
        qtystr = quantity_of_data[:len(quantity_of_data)-2]
        unit = quantity_of_data[len(quantity_of_data)-2:] 
        if(qtystr.isdigit()):
            qty = int(qtystr)
            noofBytes = qty * pow(10,3)
        else:
            hasError = True
    elif 'MB' in quantity_of_data and len(quantity_of_data)>2 :
        qtystr = quantity_of_data[:len(quantity_of_data)-2]
        unit = quantity_of_data[len(quantity_of_data)-2:] 
        if(qtystr.isdigit()):
            qty = int(qtystr)
            noofBytes = qty * pow(10,6)
        else:
            hasError = True
    elif 'GB' in quantity_of_data and len(quantity_of_data)>2:
        qtystr = quantity_of_data[:len(quantity_of_data)-2]
        unit = quantity_of_data[len(quantity_of_data)-2:] 
        if(qtystr.isdigit()):
            qty = int(qtystr)
            noofBytes = qty * pow(10,9)
        else:
            hasError = True
    elif 'TB' in quantity_of_data and len(quantity_of_data)>2:
        qtystr = quantity_of_data[:len(quantity_of_data)-2]
        unit = quantity_of_data[len(quantity_of_data)-2:] 
        if(qtystr.isdigit()):
            qty = int(qtystr)
            noofBytes = qty * pow(10,12)
        else:
            hasError = True
    elif 'KiB' in quantity_of_data and len(quantity_of_data)>3:
        qtystr = quantity_of_data[:len(quantity_of_data)-3]
        unit = quantity_of_data[len(quantity_of_data)-3:] 
        if(qtystr.isdigit()):
            qty = int(qtystr)
            noofBytes = qty * pow(2,10)
        else:
            hasError = True
    elif 'MiB' in quantity_of_data and len(quantity_of_data)>3 :
        qtystr = quantity_of_data[:len(quantity_of_data)-3]
        unit = quantity_of_data[len(quantity_of_data)-3:] 
        if(qtystr.isdigit()):
            qty = int(qtystr)
            noofBytes = qty * pow(2,20)
        else:
            hasError = True
    elif 'GiB' in quantity_of_data and len(quantity_of_data)>3:
        qtystr = quantity_of_data[:len(quantity_of_data)-3]
        unit = quantity_of_data[len(quantity_of_data)-3:] 
        if(qtystr.isdigit()):
            qty = int(qtystr)
            noofBytes = qty * pow(2,30)
        else:
            hasError = True
    elif 'TiB' in quantity_of_data and len(quantity_of_data)>3:
        qtystr = quantity_of_data[:len(quantity_of_data)-3]
        unit = quantity_of_data[len(quantity_of_data)-3:] 
        if(qtystr.isdigit()):
            qty = int(qtystr)
            noofBytes = qty * pow(2,40)
        else:
            hasError = True
    else:
        hasError = True
    
    if hasError:
       # print("Invalid data")
        return -1
    else:
        print("{}".format(noofBytes))
        return noofBytes
        
print("Correct data")
print(task3_2('2KB'))
print(task3_2('2MB'))
print(task3_2('2GB'))
print(task3_2('2TB'))
print(task3_2('2KiB'))
print(task3_2('2MiB'))
print(task3_2('2GiB'))
print(task3_2('2TiB'))

print("Error data")
print(task3_2('80KIB'))
print(task3_2('80MIB'))
print(task3_2('80GIB'))
print(task3_2('80TIB'))
print(task3_2('80kb'))

print("Error data")
print(task3_2('80KB1'))
print(task3_2('80MB2'))
print(task3_2('80GB3'))
print(task3_2('80TB4'))
print("Error data")
print(task3_2('80'))
print(task3_2('MB'))
print(task3_2('0G'))
print(task3_2('800 TB'))
# Out:
# Correct data
# 2000
# 2000
# 2000000
# 2000000
# 2000000000
# 2000000000
# 2000000000000
# 2000000000000
# 2048
# 2048
# 2097152
# 2097152
# 2147483648
# 2147483648
# 2199023255552
# 2199023255552
# Error data
# -1
# -1
# -1
# -1
# -1
# Error data
# -1
# -1
# -1
# -1
# Error data
# -1
# -1
# -1
# -1

# %%
#Task 3.2

def task3_2(quantity_of_data):
    noofBytes = 0
    hasError = False
    unit=''
    qtystr=''
    qty=0
    if ((('KB' in quantity_of_data) or  ('MB' in quantity_of_data) or ('GB' in quantity_of_data)
            or  ('TB' in quantity_of_data) ) and len(quantity_of_data)>2 ) :
        noofBytes= task3_1(quantity_of_data)
        if noofBytes==-1:
            hasError = True
    elif len(quantity_of_data)>3:
        qtystr = quantity_of_data[:len(quantity_of_data)-3]
        unit = quantity_of_data[len(quantity_of_data)-3:] 
        if(qtystr.isdigit()):
            qty = int(qtystr)
            if 'KiB' in quantity_of_data:
                noofBytes = qty * pow(2,10)
            elif 'MiB' in quantity_of_data:
                noofBytes = qty * pow(2,20)
            elif 'GiB' in quantity_of_data:
                noofBytes = qty * pow(2,30)
            elif 'TiB' in quantity_of_data:
                noofBytes = qty * pow(2,40)
            else:
                hasError = True
        else:
            hasError = True
    else:
        hasError = True
    if hasError:
        print("Invalid data")
        return -1
    else:
       # print("{}".format(noofBytes))
        return noofBytes
        
print("Correct data")
print(task3_2('2KB'))
print(task3_2('2MB'))
print(task3_2('2GB'))
print(task3_2('2TB'))
print(task3_2('2KiB'))
print(task3_2('2MiB'))
print(task3_2('2GiB'))
print(task3_2('2TiB'))

print("Error data")
print(task3_2('80KIB'))
print(task3_2('80MIB'))
print(task3_2('80GIB'))
print(task3_2('80TIB'))
print(task3_2('80kb'))

print("Error data")
print(task3_2('80KB1'))
print(task3_2('80MB2'))
print(task3_2('80GB3'))
print(task3_2('80TB4'))
print("Error data")
print(task3_2('80'))
print(task3_2('MB'))
print(task3_2('0G'))
print(task3_2('800 TB'))
# Out:
# Correct data
# 2000
# 2000000
# 2000000000
# 2000000000000
# 2048
# 2097152
# 2147483648
# 2199023255552
# Error data
# Invalid data
# -1
# Invalid data
# -1
# Invalid data
# -1
# Invalid data
# -1
# Invalid data
# -1
# Error data
# Invalid data
# 0
# Invalid data
# 0
# Invalid data
# 0
# Invalid data
# 0
# Error data
# Invalid data
# -1
# Invalid data
# -1
# Invalid data
# -1
# Invalid data
# 0

# %%
#Task3.3

def task3_3(quantity_of_data, target_unit):
    noofBytes = 0
    hasError = False
    retVal=0.0
    valid_unit = ['KB','MB','GB', 'TB','KiB','MiB','GiB', 'TiB']
    if target_unit not in valid_unit:
        hasError = True
    else:
        noofBytes = task3_2(quantity_of_data)
        if noofBytes>=0:
            if (target_unit=='KB'):
                retVal = noofBytes/pow(10,3)
            elif(target_unit=='MB'):
                retVal = noofBytes/pow(10,6)
            elif(target_unit=='GB'):
                retVal = noofBytes/pow(10,9)
            elif(target_unit=='TB'):
                retVal = noofBytes/pow(10,12)
            elif(target_unit=='KiB'):
                retVal = noofBytes/pow(2,10)
            elif(target_unit=='MiB'):
                retVal = noofBytes/pow(2,20)
            elif(target_unit=='GiB'):
                retVal = noofBytes/pow(2,30)
            elif(target_unit=='TiB'):
                retVal = noofBytes/pow(2,40)
        else:
            hasError = True
            
    if hasError:
        return -1
    else:
        return retVal

print("Convert to KB")
print("=> {}".format(task3_3("512MB","KB")))
print("=> {}".format(task3_3("512GB","KB")))
print("=> {}".format(task3_3("512TB","KB")))
print("=> {}".format(task3_3("512KiB","KB")))
print("=> {}".format(task3_3("512MiB","KB")))
print("=> {}".format(task3_3("512GiB","KB")))
print("=> {}".format(task3_3("512TiB","KB")))
print()
print("Convert to MB")
print("=> {}".format(task3_3("512KB","MB")))
print("=> {}".format(task3_3("512GB","MB")))
print("=> {}".format(task3_3("512TB","MB")))
print("=> {}".format(task3_3("512KiB","KB")))
print("=> {}".format(task3_3("512MiB","KB")))
print("=> {}".format(task3_3("512GiB","KB")))
print("=> {}".format(task3_3("512TiB","KB")))
print()
print("Convert to GB")
print("=> {}".format(task3_3("512KB","GB")))
print("=> {}".format(task3_3("512MB","GB")))
print("=> {}".format(task3_3("512TB","GB")))
print("=> {}".format(task3_3("512KiB","GB")))
print("=> {}".format(task3_3("512MiB","GB")))
print("=> {}".format(task3_3("512GiB","GB")))
print("=> {}".format(task3_3("512TiB","GB")))
print()
print("Convert to TB")
print("=> {}".format(task3_3("512KB","TB")))
print("=> {}".format(task3_3("512MB","TB")))
print("=> {}".format(task3_3("512GB","TB")))
print("=> {}".format(task3_3("512KiB","TB")))
print("=> {}".format(task3_3("512MiB","TB")))
print("=> {}".format(task3_3("512GiB","TB")))
print("=> {}".format(task3_3("512TiB","TB")))
print()
print("Convert to KiB")
print("=> {}".format(task3_3("512KB","KiB")))
print("=> {}".format(task3_3("512MB","KiB")))
print("=> {}".format(task3_3("512GB","KiB")))
print("=> {}".format(task3_3("512TB","KiB")))
print("=> {}".format(task3_3("512GiB","KiB")))
print("=> {}".format(task3_3("512MiB","KiB")))
print("=> {}".format(task3_3("512TiB","KiB")))
print()
print("Convert to MiB")
print("=> {}".format(task3_3("512KB","MiB")))
print("=> {}".format(task3_3("512MB","MiB")))
print("=> {}".format(task3_3("512GB","MiB")))
print("=> {}".format(task3_3("512TB","MiB")))
print("=> {}".format(task3_3("512KiB","MiB")))
print("=> {}".format(task3_3("512GiB","MiB")))
print("=> {}".format(task3_3("512TiB","MiB")))
print()
print("Convert to GiB")
print("=> {}".format(task3_3("512KB","GiB")))
print("=> {}".format(task3_3("512MB","GiB")))
print("=> {}".format(task3_3("512GB","GiB")))
print("=> {}".format(task3_3("512TB","GiB")))
print("=> {}".format(task3_3("512KiB","GiB")))
print("=> {}".format(task3_3("512MiB","GiB")))
print("=> {}".format(task3_3("512TiB","GiB")))
print()
print("Convert to TiB")
print("=> {}".format(task3_3("512KB","TiB")))
print("=> {}".format(task3_3("512MB","TiB")))
print("=> {}".format(task3_3("512GB","TiB")))
print("=> {}".format(task3_3("512TB","TiB")))
print("=> {}".format(task3_3("512KiB","TiB")))
print("=> {}".format(task3_3("512MiB","TiB")))
print("=> {}".format(task3_3("512GiB","TiB")))


print()
print("3 different set of data")
print("=> {}".format(task3_3("512MiB","GiB")))
print("=> {}".format(task3_3("512GiB","GiB")))
print("=> {}".format(task3_3("512MiX","GiB")))  
print("=> {}".format(task3_3("512Mi","GiX")))
# Out:
# Convert to KB
# => 512000.0
# => 512000000.0
# => 512000000000.0
# => 524.288
# => 536870.912
# => 549755813.888
# => 562949953421.312
#
# Convert to MB
# => 0.512
# => 512000.0
# => 512000000.0
# => 524.288
# => 536870.912
# => 549755813.888
# => 562949953421.312
#
# Convert to GB
# => 0.000512
# => 0.512
# => 512000.0
# => 0.000524288
# => 0.536870912
# => 549.755813888
# => 562949.953421312
#
# Convert to TB
# => 5.12e-07
# => 0.000512
# => 0.512
# => 5.24288e-07
# => 0.000536870912
# => 0.549755813888
# => 562.949953421312
#
# Convert to KiB
# => 500.0
# => 500000.0
# => 500000000.0
# => 500000000000.0
# => 536870912.0
# => 524288.0
# => 549755813888.0
#
# Convert to MiB
# => 0.48828125
# => 488.28125
# => 488281.25
# => 488281250.0
# => 0.5
# => 524288.0
# => 536870912.0
#
# Convert to GiB
# => 0.000476837158203125
# => 0.476837158203125
# => 476.837158203125
# => 476837.158203125
# => 0.00048828125
# => 0.5
# => 524288.0
#
# Convert to TiB
# => 4.6566128730773926e-07
# ...
